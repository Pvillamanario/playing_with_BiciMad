# %%
import pandas as pd

# %%
df_bicimad = pd.read_csv('../data/BiciMad.csv')
df_bicimad.head()
# Out:
#    id                name  light number  \
# 0   1    Puerta del Sol A      2     1a
# 1   2    Puerta del Sol B      1     1b
# 2   3         Miguel Moya      2      2
# 3   4  Plaza Conde Suchil      0      3
# 4   5            Malasaña      2      4
#
#                                     address  activate  no_available  \
# 0                       Puerta del Sol nº 1         1             0
# 1                       Puerta del Sol nº 1         1             0
# 2                    Calle Miguel Moya nº 1         1             0
# 3  Plaza del Conde del Valle de Súchil nº 3         1             0
# 4               Calle Manuela Malasaña nº 5         1             0
#
#    total_bases  dock_bikes  free_bases  reservations_count geometry_type  \
# 0           30          15          11                   0         Point
# 1           30          22           4                   0         Point
# 2           24          12          11                   0         Point
# ...

# %%
df_points_int = pd.read_csv('../data/datasets_ayto.csv')
df_points_int.head()
# Out:
#                               dataset  \
# 0  Aparcamientos públicos municipales
# 1  Aparcamientos públicos municipales
# 2  Aparcamientos públicos municipales
# 3  Aparcamientos públicos municipales
# 4  Aparcamientos públicos municipales
#
#                                                 name                 address  \
# 0          Aparcamiento disuasorio Aviación Española  CALLE FUENTE DE LIMA 5
# 1  Aparcamiento disuasorio Estadio Metropolitano ...   AVENIDA ARCENTALES 37
# 2          Aparcamiento disuasorio Fuente de la Mora     CALLE DULCE CHACON
# 3                    Aparcamiento disuasorio Islazul      CALLE CALDERILLA 1
# 4                      Aparcamiento disuasorio Pitis   CALLE GLORIA FUERTES
#
#   zip_code           longitude            latitude
# 0    28024           -3.783593           40.383353
# 1    28022           -3.598831           40.434154
# 2    28050  -3.664502512734404   40.48444286881538
# 3    28054  -3.737923481612698   40.36521668890186
# ...
